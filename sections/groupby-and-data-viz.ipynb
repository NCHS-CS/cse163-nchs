# %% [markdown]
# ## Hierarchal Indexing & Data Visualization
# In this lession, we will practice working with multi-indexed dataframes and data visualization tools learned this week.

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Our Dataset!
# Run the cell below to see the DataFrame you'll be working with today.

# %%
scoreboard = pd.DataFrame({
    "Player": ["Arona", "Anaya", "Thrisha", "Arpan", "Sonoma", "Asmi", "Alyssa", "Laura", "Alexis",
               "Sheamin", "Kevin", "MarioKartLegend"],
    "FavoriteTrack": ["Bowser’s Castle", "Rainbow Road", "Toad Harbor", "Big Blue", "Cheese Land", 
 "Toad Harbor", "Mario Circuit", "Bowser's Castle", "Mario Circuit", 
 "Coconut Mall", "Mario Circuit", "Cheese Land"],
    "Coins": [9, 8, 8, 9, 9, 11, 9, 7, 9, 8, 9, 10],
    "Mushrooms": [2, 0, 3, 1, 2, 2, 0, 3, 3, 1, 2, 3],
    "TopSpeed": [150, 70, 60, 125, 30, 20, 80, 94, 10, 77, 23, 49],
    "Character": ["Monty Mole", "Yoshi", "Luigi", "Blue Toad", "Toadette", "Princess Peach", 
                  "Princess Daisy", "Waluigi", "King Boo", "Bowser", "Mario", "Wario"],
    "Drivetrain": ["Bike", "Car", "4 wheeler", "Car", "Stroller", "4 wheeler", "Car", "Bike", 
                   "Stroller", "4 wheeler", "Bike", "Bike"],
    "Playstyle": ["Aggressive", "Aggressive", "Resourceful", "Speedster", "Resourceful", "Resourceful",
                  "Balanced", "Aggressive", "Balanced", "Balanced", "Balanced", "Resourceful"]
})

scoreboard
# Out:
#              Player    FavoriteTrack  Coins  Mushrooms  TopSpeed  \
# 0             Arona  Bowser’s Castle      9          2       150
# 1             Anaya     Rainbow Road      8          0        70
# 2           Thrisha      Toad Harbor      8          3        60
# 3             Arpan         Big Blue      9          1       125
# 4            Sonoma      Cheese Land      9          2        30
# 5              Asmi      Toad Harbor     11          2        20
# 6            Alyssa    Mario Circuit      9          0        80
# 7             Laura  Bowser's Castle      7          3        94
# 8            Alexis    Mario Circuit      9          3        10
# 9           Sheamin     Coconut Mall      8          1        77
# 10            Kevin    Mario Circuit      9          2        23
# 11  MarioKartLegend      Cheese Land     10          3        49
#
#          Character Drivetrain    Playstyle
# 0       Monty Mole       Bike   Aggressive
# 1            Yoshi        Car   Aggressive
# 2            Luigi  4 wheeler  Resourceful
# 3        Blue Toad        Car    Speedster
# 4         Toadette   Stroller  Resourceful
# 5   Princess Peach  4 wheeler  Resourceful
# 6   Princess Daisy        Car     Balanced
# 7          Waluigi       Bike   Aggressive
# 8         King Boo   Stroller     Balanced
# 9           Bowser  4 wheeler     Balanced
# 10           Mario       Bike     Balanced
# 11           Wario       Bike  Resourceful

# %% [markdown]
# ## Practice Problems
# Find the `Player` with the most `Coins`.

# %%
# TODO: Who has the most coins?
# Out:
# 'Asmi'

# %% [markdown]
# Find the average `TopSpeed` for each `Playstyle` category.

# %%
# TODO: What's the average speed of Aggressive players?
# Out:
# Playstyle
# Aggressive     104.666667
# Balanced        47.500000
# Resourceful     39.750000
# Speedster      125.000000
# Name: TopSpeed, dtype: float64

# %% [markdown]
# Create both a line plot and a bar plot to visualize `TopSpeed` trends by `Playstyle`. Compare the effectiveness of each in identifying patterns or outliers.

# %%
# TODO: Visualize!

# %% [markdown]
# ## Hierarchal Indexing

# %% [markdown]
# What if we wanted to set the index of our DataFrame to be 2 columns? Set the indices to `Drivetrain` and `FavoriteTrack` and then find all the `Bike`rs who like `Bowser's Castle`.

# %%
# TODO: Which Bikers like Bowser's?
# Out:
# /tmp/ipykernel_244/190171512.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   scoreboard.loc[("Bike", "Bowser's Castle")]
#                            Player  Coins  Mushrooms  TopSpeed Character  \
# Drivetrain FavoriteTrack
# Bike       Bowser's Castle  Laura      7          3        94   Waluigi
#
#                              Playstyle
# Drivetrain FavoriteTrack
# Bike       Bowser's Castle  Aggressive

# %% [markdown]
# Next, find how many `Mushrooms` and `Coins` the `Bike` drivers have.

# %%
# TODO: How many Mushrooms and Coins do Bikers have?
# Out:
#                             Mushrooms  Coins
# Drivetrain FavoriteTrack
# Bike       Bowser’s Castle          2      9
#            Bowser's Castle          3      7
#            Mario Circuit            2      9
#            Cheese Land              3     10

# %% [markdown]
# Next, find the `Player` with the most `Coins` out of all `Bike` drivers.

# %%
# TODO: Which Biker has the most coins?
# Out:
# /tmp/ipykernel_244/1182762080.py:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   scoreboard.loc[highest_coins, "Player"]
# Drivetrain  FavoriteTrack
# Bike        Cheese Land      MarioKartLegend
# Name: Player, dtype: object
